# %% [markdown]
# <a href="https://colab.research.google.com/github/mhhaider6/Data_Analytics_bootcamp/blob/main/airlifthaider.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import missingno as mn

# %%
# Lets load the data for Airlift here
df = pd.read_csv(r'/content/airlift case study data.csv')

# %%
df.head(100)
# Out:
#     customerId  week  first_trip_week  rides
# 0          156    44               36      2
# 1          164    44               38      6
# 2          224    42               36      5
# 3          224    43               36      4
# 4          224    44               36      5
# ..         ...   ...              ...    ...
# 95        5198    42               34      1
# 96        5385    42               40      2
# 97        5507    42               36      6
# 98        5507    43               36      9
# 99        5507    44               36     11
#
# [100 rows x 4 columns]

# %%
mn.bar(df)
# Out:
# <Axes: >

# %%
# @title Distribution of Rides per Week

import matplotlib.pyplot as plt
import pandas as pd

# Assuming your data is in a pandas DataFrame called 'df'
plt.figure(figsize=(10, 6))
for week in df['week'].unique():
    subset = df[df['week'] == week]
    plt.hist(subset['rides'], bins=10, alpha=0.5, label=f'Week {week}')
plt.xlabel('Number of Rides')
plt.ylabel('Frequency')
plt.title('Distribution of Rides per Week')
_ = plt.legend()

# %% [markdown]
# # Here we can see that after 2 to 3 rides there is a significant reduction in number of rides. This means that the average user is using anywhere between 2-3 rides in a week.

# %%
# @title customerId

from matplotlib import pyplot as plt
df['customerId'].plot(kind='hist', bins=20, title='customerId')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# # We can see that customers with IDs in 50k and 250k there were most number of frequency of rides. futher investigation can be done to see why this is the case.

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['week']
  ys = series['rides']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = _df_10.sort_values('week', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('week')
_ = plt.ylabel('rides')

# %% [markdown]
# # Reduction in number of rides

# %% [markdown]
# # NEW DATA SET

# %%
df = pd.read_csv(r'/content/global-data-on-sustainable-energy (1).csv')

# %%
print(df.head())
# Out:
#         Entity  Year  Access to electricity (% of population)  \
# 0  Afghanistan  2000                                 1.613591
# 1  Afghanistan  2001                                 4.074574
# 2  Afghanistan  2002                                 9.409158
# 3  Afghanistan  2003                                14.738506
# 4  Afghanistan  2004                                20.064968
#
#    Access to clean fuels for cooking  \
# 0                                6.2
# 1                                7.2
# 2                                8.2
# 3                                9.5
# 4                               10.9
#
#    Renewable-electricity-generating-capacity-per-capita  \
# 0                                               9.22
# 1                                               8.86
# 2                                               8.47
# 3                                               8.09
# 4                                               7.75
#
# ...

# %%
print(df.isnull().sum())
# Out:
# Entity                                                                 0
# Year                                                                   0
# Access to electricity (% of population)                               10
# Access to clean fuels for cooking                                    169
# Renewable-electricity-generating-capacity-per-capita                 931
# Financial flows to developing countries (US $)                      2089
# Renewable energy share in the total final energy consumption (%)     194
# Electricity from fossil fuels (TWh)                                   21
# Electricity from nuclear (TWh)                                       126
# Electricity from renewables (TWh)                                     21
# Low-carbon electricity (% electricity)                                42
# Primary energy consumption per capita (kWh/person)                     0
# Energy intensity level of primary energy (MJ/$2017 PPP GDP)          207
# ...

# %%
df.head(100)
# Out:
#                  Entity  Year  Access to electricity (% of population)  \
# 0           Afghanistan  2000                                 1.613591
# 1           Afghanistan  2001                                 4.074574
# 2           Afghanistan  2002                                 9.409158
# 3           Afghanistan  2003                                14.738506
# 4           Afghanistan  2004                                20.064968
# ..                  ...   ...                                      ...
# 95  Antigua and Barbuda  2011                                94.552020
# 96  Antigua and Barbuda  2012                               100.000000
# 97  Antigua and Barbuda  2013                               100.000000
# 98  Antigua and Barbuda  2014                               100.000000
# 99  Antigua and Barbuda  2015                               100.000000
#
#     Access to clean fuels for cooking  \
# 0                                 6.2
# ...
